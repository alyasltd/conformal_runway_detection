# %% [markdown]
# #### **Visualisation**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import sys

# %%
df_results_v5a = pd.read_csv("results_v5a.csv")
df_results_v5m = pd.read_csv("results_v5m.csv")
df_results_v6a = pd.read_csv("results_v6_a.csv")
df_results_v6m = pd.read_csv("results_v6_m.csv")

df_results_v5a_synth = pd.read_csv("results_v5_synth_a.csv")
df_results_v6a_synth = pd.read_csv("results_v6_synth_a.csv")
df_results_v5m_synth = pd.read_csv("results_v5_synth_m.csv")
df_results_v6m_synth = pd.read_csv("results_v6_synth_m.csv")

# %%
sns.set_style("whitegrid")
plt.rcParams.update({
    "font.size": 12,
    "axes.titlesize": 16,
    "axes.labelsize": 14,
    "legend.fontsize": 12
})

palette = {
    "YOLOv6": "#340cb2",  # violet prune
    "YOLOv5": "#D35400",  # orange brûlé
}

# %% [markdown]
# ##### **IOU pred VS IOU pred C**

# %%
# --- IoU pred vs IoU pred C (global - additive) ---
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_results_v5a, x="iou_pred_gt", y="iou_pred_c_gt",
                marker="*", s=150, color=palette["YOLOv5"], alpha=0.7, label="YOLOv5 - Additive")
sns.scatterplot(data=df_results_v6a, x="iou_pred_gt", y="iou_pred_c_gt",
                marker="^", s=100, color=palette["YOLOv6"], alpha=0.7, label="YOLOv6 - Additive")
plt.xlabel("YOLO Prediction IoU")
plt.ylabel("IoU after conformal prediction")
#plt.title("IoU pred vs IoU pred C (Global - Additive)")
plt.legend()
plt.tight_layout()
plt.savefig("/home/aws_install/conformal_runway_detection/plots/iou_pred_vs_iou_pred_c_additive.png", dpi=300)
plt.show()

# --- IoU pred vs IoU pred C (global - multiplicative) ---
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_results_v5m, x="iou_pred_gt", y="iou_pred_c_gt",
                marker="*", s=150, color=palette["YOLOv5"], alpha=0.7, label="YOLOv5 - Multiplicative")
sns.scatterplot(data=df_results_v6m, x="iou_pred_gt", y="iou_pred_c_gt",
                marker="^", s=100, color=palette["YOLOv6"], alpha=0.7, label="YOLOv6 - Multiplicative")
plt.xlabel("YOLO Prediction IoU")
plt.ylabel("IoU after conformal prediction")
#plt.title("IoU pred vs IoU pred C (Global - Multiplicative)")
plt.legend()
plt.tight_layout()
plt.savefig("/home/aws_install/conformal_runway_detection/plots/iou_pred_vs_iou_pred_c_multiplicative.png", dpi=300)
plt.show()

# %% [markdown]
# ##### **IOA pred VS IOA pred C**

# %%
# ---  IoA pred vs IoA pred C (global - additive) ---
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_results_v5a, x="ioa_pred_gt", y="ioa_pred_c_gt",
                marker="*", s=150, color=palette["YOLOv5"], alpha=0.7, label="YOLOv5 - Additive")
sns.scatterplot(data=df_results_v6a, x="iou_pred_gt", y="iou_pred_c_gt",
                marker="^", s=100, color=palette["YOLOv6"], alpha=0.7, label="YOLOv6 - Additive")
plt.xlabel("YOLO Prediction IoA")
plt.ylabel("Conformal Prediction IoA")
#plt.title("IoA pred vs IoA pred C (Global - Additive)")
plt.legend()
plt.tight_layout()
plt.savefig("/home/aws_install/conformal_runway_detection/plots/ioa_pred_vs_ioa_pred_c_additive.png", dpi=300)
plt.show()


# ---  IoA pred vs IoA pred C (global - multiplicative) ---
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_results_v5m, x="ioa_pred_gt", y="ioa_pred_c_gt",
                marker="*", s=150, color=palette["YOLOv5"], alpha=0.7, label="YOLOv5 - Multiplicative")
sns.scatterplot(data=df_results_v6m, x="iou_pred_gt", y="iou_pred_c_gt",
                marker="^", s=100, color=palette["YOLOv6"], alpha=0.7, label="YOLOv6 - Multiplicative")
plt.xlabel("YOLO Prediction IoA")
plt.ylabel("Conformal Prediction IoA")
#plt.title("IoA pred vs IoA pred C (Global - Multiplicative)")
plt.legend()
plt.tight_layout()
plt.savefig("/home/aws_install/conformal_runway_detection/plots/ioa_pred_vs_ioa_pred_c_multiplicative.png", dpi=300)
plt.show()

# %% [markdown]
# ##### **IOA pred C VS IOU pred C**

# %%
# ---  IoA pred vs IoU pred C (global - additive) --- 
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_results_v5a, x="ioa_pred_c_gt", y="iou_pred_c_gt",
                marker="*", s=150, color=palette["YOLOv5"], alpha=0.7, label="YOLOv5 - Additive")
sns.scatterplot(data=df_results_v6a, x="ioa_pred_c_gt", y="iou_pred_c_gt",
                marker="^", s=100, color=palette["YOLOv6"], alpha=0.7, label="YOLOv6 - Additive")
plt.xlabel("IoA Conformal Prediction")
plt.ylabel("IoU Conformal Prediction")
#plt.title("IoA pred vs IoU pred C (Global - Additive)")
plt.legend()
plt.tight_layout()

plt.savefig("/home/aws_install/conformal_runway_detection/plots/ioa_pred_vs_iou_pred_c_additive.png", dpi=300)

plt.show()

# ---  IoA pred vs IoU pred C (global - multiplicative) --- 
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_results_v5m, x="ioa_pred_c_gt", y="iou_pred_c_gt",
                marker="*", s=150, color=palette["YOLOv5"], alpha=0.7, label="YOLOv5 - Multiplicative")
sns.scatterplot(data=df_results_v6m, x="ioa_pred_c_gt", y="iou_pred_c_gt",
                marker="^", s=100, color=palette["YOLOv6"], alpha=0.7, label="YOLOv6 - Multiplicative")
plt.xlabel("IoA Conformal Prediction")
plt.ylabel("IoU Conformal Prediction")
#plt.title("IoA pred vs IoU pred C (Global - Multiplicative)")
plt.legend()
plt.tight_layout()

plt.savefig("/home/aws_install/conformal_runway_detection/plots/ioa_pred_vs_iou_pred_c_multiplicative.png", dpi=300)

plt.show()

# %% [markdown]
# ##### **IOU pred C VS slant distance**

# %%
# ---  IoU pred C vs Slant Distance (synthetic - additive) --- 
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_results_v5a_synth, x="slant_distance", y="iou_pred_c_gt",
                marker="*", s=150, color=palette["YOLOv5"], alpha=0.7, label="YOLOv5 - Additive Synth")
sns.scatterplot(data=df_results_v6a_synth, x="slant_distance", y="iou_pred_c_gt",
                marker="^", s=100, color=palette["YOLOv6"], alpha=0.7, label="YOLOv6 - Additive Synth")
plt.xlabel("Slant Distance")
plt.ylabel("Conformal IoU Prediction")
#plt.title("IoU pred C vs Slant Distance (Synthetic - Additive)")
plt.legend()
plt.tight_layout()

plt.savefig("/home/aws_install/conformal_runway_detection/plots/iou_pred_c_vs_slant_distance_additive.png", dpi=300)

plt.show()

# --- IoU pred C vs Slant Distance (synthetic - multiplicative) --- 
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_results_v5m_synth, x="slant_distance", y="iou_pred_c_gt",
                marker="*", s=150, color=palette["YOLOv5"], alpha=0.7, label="YOLOv5 - Multiplicative Synth")
sns.scatterplot(data=df_results_v6m_synth, x="slant_distance", y="iou_pred_c_gt",
                marker="^", s=100, color=palette["YOLOv6"], alpha=0.7, label="YOLOv6 - Multiplicative Synth")
plt.xlabel("Slant Distance")
plt.ylabel("Conformal IoU Prediction")
#plt.title("IoU pred C vs Slant Distance (Synthetic - Multiplicative)")
plt.legend()
plt.tight_layout()

plt.savefig("/home/aws_install/conformal_runway_detection/plots/iou_pred_c_vs_slant_distance_multiplicative.png", dpi=300)

plt.show()
