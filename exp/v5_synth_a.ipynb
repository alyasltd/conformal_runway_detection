# %% [markdown]
# # **V5 on Synthetic Datatest**

# %%
import sys
import os
current_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(current_dir, '..')))

from utils.wrapper import YOLOAPIWrappper
from utils.pipeline import CPPipeline

# %% [markdown]
# ### **Additive**

# %%
v5 = '../utils/v5/bestv5.onnx'
yolov5_detector_synth = YOLOAPIWrappper(v5,file_path='../calibration/calibv5_synth_a.pickle', conf_thres=0.7, iou_thres=0.5)
pipev5_synth = CPPipeline(yolov5_detector_synth, test_set='test_synth', method='additive')

# %%
X_train, y_train, labels_train= pipev5_synth.extract_yolo_dataset()
X_train, X_val, y_train, y_val, labels_train, labels_val = pipev5_synth.calibration_and_val(X_train, y_train, labels_train)

# %%
conformal_predictor = pipev5_synth.pipeline( X_train=X_train, y_train= y_train, labels_train= labels_train)
# Out:
# Predictions: [[1345.57763672 1239.2442627  1618.08813477 1438.55651855]
#  [ 886.05023193  982.3972168  1111.93261719 1164.37670898]
#  [ 655.53692627 1250.96252441  708.29278564 1317.50183105]
#  ...
#  [ 589.39331055 1047.36291504  843.47033691 1175.39343262]
#  [ 639.62579346 1094.87536621  817.97613525 1225.84802246]
#  [1565.59301758 1080.66894531 1817.16357422 1245.32128906]]
# Matched Ground Truths: [[1339. 1240. 1610. 1440.]
#  [ 879.  985. 1118. 1164.]
#  [ 650. 1254.  708. 1322.]
#  ...
#  [ 593. 1044.  846. 1172.]
#  [ 640. 1095.  811. 1227.]
#  [1567. 1086. 1809. 1243.]]
# Images: ['/home/aws_install/data/yolo_database/images/test_synth/WSSS_02L_35_23.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LEMD_32R_35_21.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/RJAA_34R_35_05.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/MDSD_17_35_28.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LFRS_21_35_05.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LFRS_03_35_21.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LOWL_26_35_15.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/CYYZ_23_35_29.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/RJTT_04_35_18.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LOWL_8_35_00.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LICJ_20_35_27.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/VOTV_32_35_13.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/VOTV_14_35_32.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LICJ_02_35_30.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/EDDV_27R_35_12.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/RJAA_34R_35_29.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/SEQM_18_35_24.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/FTTJ_5_35_06.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/KIAH_26R_35_10.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/HTDA_5_35_15.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/GCRR_03_35_10.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LOWL_26_35_24.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/KIAH_26R_35_09.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/YBBN_01_35_19.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LTAI_36R_35_08.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/CYUL_24R_35_10.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/VHHH_25R_35_06.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/RJTT_22_35_22.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/YBBN_01_35_07.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/FMEP_33_35_10.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/SAEZ_35_35_11.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/ZBAA_36R_35_18.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/ZBAA_19_35_17.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/RPMD_23_35_09.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/SEQM_18_35_11.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/CYVR_26R_35_10.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/FTTJ_5_35_27.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LGSM_27_35_17.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LFRN_28_35_01.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LCPH_29_35_28.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LTAI_36R_35_13.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LTAI_36R_35_29.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/LICJ_25_35_13.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/GCRR_03_35_27.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/FMEP_33_35_03.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/EDDV_27R_35_26.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/RJAA_16L_35_25.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/ZBAA_36R_35_29.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/YMLT_32L_35_00.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/SAEZ_35_35_01.jpeg', '/home/aws_install/data/yolo_database/images/test_synth/FTTJ_5_35_30.jpeg', '/home/aws_install/data/yolo_database/images/test_s ...
# Classes: [0. 0. 0. ... 0. 0. 0.]

# %%
pipev5_synth.infer_eval_single_image(
    conformal_predictor, 
    X_val[5],  # Image path at index 5
    y_val[5],  # Ground truth bounding boxes at index 5
    labels_val[5],  # Labels at index 5
    None  # `y_new_api` is set to None, so the function will compute it internally
)
# Out:
# Marginal coverage: 1.0
# Average area: 45753.578125

# %%
y_pred_val, y_true_val, images_val, classes_val, box_inner_val, box_outer_val = pipev5_synth.infer_all_images(conformal_predictor,X_val, y_val, labels_val, visualize = False)
# Out:
# Number of images: 443
# Number of images without predictions: 31
# Number of images with predictions: 412

# %%
average_glo_area, cover = pipev5_synth.average_cover_and_area(y_pred_val, y_true_val, box_outer_val)
# Out:
# Average area of prediction intervals: 79950.6953125
# Average length of prediction intervals: 282.75555419921875
# Average Marginal coverage: 0.7669902912621359
